# %%
import pandas as pd
import requests
import json

# %%
df=pd.read_csv("resources//API_EN.ATM.CO2E.KT_DS2_en_csv_v2_3470002.csv")

# %%
df.head()
# Out:
#                   Country Name Country Code      Indicator Name  \
# 0                        Aruba          ABW  CO2 emissions (kt)
# 1  Africa Eastern and Southern          AFE  CO2 emissions (kt)
# 2                  Afghanistan          AFG  CO2 emissions (kt)
# 3   Africa Western and Central          AFW  CO2 emissions (kt)
# 4                       Angola          AGO  CO2 emissions (kt)
#
#    Indicator Code           1960          1961           1962          1963  \
# 0  EN.ATM.CO2E.KT   11092.675000   11576.71900   12713.489000   12178.10700
# 1  EN.ATM.CO2E.KT  118545.901306  123758.90333  128093.897815  132810.33253
# 2  EN.ATM.CO2E.KT     414.371000     491.37800     689.396000     707.73100
# 3  EN.ATM.CO2E.KT    8760.463000    9376.51900    9710.216000   11540.04900
# 4  EN.ATM.CO2E.KT     550.050000     454.70800    1180.774000    1151.43800
#
#             1964           1965  ...           2012           2013  \
# ...

# %%
df = df.drop(df.columns[[2,3]], axis = 1)

# %%
df_rotated = df.melt(id_vars=["Country Name", "Country Code"], 
        var_name="Year", 
        value_name="CO2 Emissions KT")

# %%
df_rotated.head()
# Out:
#                   Country Name Country Code  Year  CO2 Emissions KT
# 0                        Aruba          ABW  1960      11092.675000
# 1  Africa Eastern and Southern          AFE  1960     118545.901306
# 2                  Afghanistan          AFG  1960        414.371000
# 3   Africa Western and Central          AFW  1960       8760.463000
# 4                       Angola          AGO  1960        550.050000

# %%
from datetime import datetime
timestampStr = datetime.now().date().strftime("%d-%b-%Y")

parsedDf = json.loads((df_rotated).to_json(orient="records"))

with open('emissions_data_by_country_1960-2020-'+timestampStr+'.json', 'w') as outfile:
     json.dump(parsedDf , outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)
